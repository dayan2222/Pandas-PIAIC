# %% [markdown]
# <a href="https://colab.research.google.com/github/dayan2222/Pandas-PIAIC/blob/master/WebScraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
tables = pd.read_html('https://www.psx.com.pk/psx/announcement/financial-announcements')
# tables variable type is not dataframe, its list
print(type(tables))
print(len(tables))
# Out:
# <class 'list'>
# 1

# %%
stock = tables[0]
stock
# Out:
#                                   Company  ... Closure Of Share Transfer Books
# 0                            Feb 07, 2020  ...                    Feb 07, 2020
# 1        Sazgar Engineering Works Limited  ...         21/03/2020 - 27/03/2020
# 2              EFU Life Assurance Limited  ...         21/03/2020 - 27/03/2020
# 3         Engro Powergen Qadirpur Limited  ...         18/03/2020 - 24/03/2020
# 4                     Allied Bank Limited  ...                               -
# ...                                   ...  ...                             ...
# 1302                         Aug 09, 2019  ...                    Aug 09, 2019
# 1303              Emco Industries Limited  ...         10/09/2019 - 17/09/2019
# 1304              Pakistan Cables Limited  ...         20/09/2019 - 27/09/2019
# 1305  Century Paper & Board Mills Limited  ...         20/09/2019 - 26/09/2019
# 1306               Bestway Cement Limited  ...         17/09/2019 - 23/09/2019
#
# [1307 rows x 9 columns]

# %%
print(pd.DataFrame(stock.head()))
stock.drop(stock.index[0])
# Out:
#                             Company  ... Closure Of Share Transfer Books
# 0                      Feb 07, 2020  ...                    Feb 07, 2020
# 1  Sazgar Engineering Works Limited  ...         21/03/2020 - 27/03/2020
# 2        EFU Life Assurance Limited  ...         21/03/2020 - 27/03/2020
# 3   Engro Powergen Qadirpur Limited  ...         18/03/2020 - 24/03/2020
# 4               Allied Bank Limited  ...                               -
#
# [5 rows x 9 columns]
#                                   Company  ... Closure Of Share Transfer Books
# 1        Sazgar Engineering Works Limited  ...         21/03/2020 - 27/03/2020
# 2              EFU Life Assurance Limited  ...         21/03/2020 - 27/03/2020
# 3         Engro Powergen Qadirpur Limited  ...         18/03/2020 - 24/03/2020
# 4                     Allied Bank Limited  ...                               -
# 5                     Allied Bank Limited  ...         18/02/2020 - 27/02/2020
# ...

# %%
print(type(stock))
print(len(stock))
print(stock.shape)
print(stock.columns)

print(stock["Company"].head())
print(stock["Profit / (Loss) Before Taxation (Rs. In Million)"].head())
stock.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# 1307
# (1307, 9)
# Index(['Company', 'Time', 'Year ended /Half Year ended',
#        'Dividend / Bonus / Right',
#        'Profit / (Loss) Before Taxation (Rs. In Million)',
#        'Profit / (Loss) After Taxation (Rs. In Million)', 'EPS /(LPS)',
#        'Annual General Meeting / E.O.G.M.', 'Closure Of Share Transfer Books'],
#       dtype='object')
# 0                        Feb 07, 2020
# 1    Sazgar Engineering Works Limited
# 2          EFU Life Assurance Limited
# 3     Engro Powergen Qadirpur Limited
# 4                 Allied Bank Limited
# Name: Company, dtype: object
# 0       Feb 07, 2020
# 1                  -
# 2           2354.173
# 3           3406.003
# 4    24,701.923 (CS)
# Name: Profit / (Loss) Before Taxation (Rs. In Million), dtype: object
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ...

# %%
stock[stock['Company'].str.match('Sazgar Engineering Works Limited')]
# Out:
#                                Company  ... Closure Of Share Transfer Books
# 1     Sazgar Engineering Works Limited  ...         21/03/2020 - 27/03/2020
# 566   Sazgar Engineering Works Limited  ...                               -
# 1051  Sazgar Engineering Works Limited  ...         19/10/2019 - 26/10/2019
#
# [3 rows x 9 columns]
